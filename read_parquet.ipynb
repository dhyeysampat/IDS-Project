# %%
import pandas as pd

# Note: path is to folder
D = pd.read_parquet('./data/traficom_open_data_for_vehicles')
print(D.shape)
D.head()
# Out:
# (5373623, 41)
#   vehicle_classification date_of_first_registration  vehicle_subclass  usage  \
# 0                     L3                 2003-06-10             109.0    1.0
# 1                    MUU                       None              21.0    1.0
# 2                    MUU                 1976-09-01              13.0    1.0
# 3                     M1                 1984-07-09               NaN    1.0
# 4                    MUU                 1983-09-22              13.0    1.0
#
#   variant_uid version_uid date_of_use color  n_doors body_type  ...  \
# 0        None        None  2003-06-10     0      NaN      None  ...
# 1        None        None        None  None      NaN      None  ...
# 2        None        None        None  None      NaN      None  ...
# 3        None        None        None     1      NaN      None  ...
# 4        None        None        None  None      NaN      None  ...
#
#    type_approval_number  driving_power_euro_vi  municipality  NEDC_Co2  \
# ...

# %%
D = pd.read_parquet('./data/tax_admin_applied_car_tax_data')
print(D.shape)
D.head()
# Out:
# (36558, 19)
#          make model     model_specifier condition_h_bad_n_normal_y_good  \
# 0  ALFA ROMEO   147      1.6 3D HB 88KW                               N
# 1  ALFA ROMEO   156  1.9 D 4D STW 103KW                               N
# 2  ALFA ROMEO   156  1.9 D 5D STW 103KW                               N
# 3  ALFA ROMEO   156   1.9 D 5D STW 85KW                               N
# 4  ALFA ROMEO   159       1.9 D 4D 88KW                               N
#
#   date_of_decision date_of_use  odometer_unit_1000km  taxable_value  car_tax  \
# 0       2011-11-21  2007-03-31                  57.0        7337.80  2091.27
# 1       2011-11-02  2004-03-15                 146.0        6227.00  1525.61
# 2       2011-11-10  2004-06-25                 104.0        6978.00  1709.61
# 3       2011-11-22  2003-11-04                 194.0        4258.00  1038.95
# 4       2011-11-01  2007-01-31                  65.0       14012.05  3362.89
#
# ...
